# %%
import requests
from bs4 import BeautifulSoup
import json
# This is the function that allow the results to be sent to google form
def send_to_google_form(data_dict, form_url):
    ''' Helper function to upload information to a corresponding google form 
        You are not expected to follow the code within this function!
    '''
    form_id = form_url[34:90]
    view_form_url = f'https://docs.google.com/forms/d/e/{form_id}/viewform'
    post_form_url = f'https://docs.google.com/forms/d/e/{form_id}/formResponse'

    page = requests.get(view_form_url)
    content = BeautifulSoup(page.content, "html.parser").find('script', type='text/javascript')
    content = content.text[27:-1]
    result = json.loads(content)[1][1]
    form_dict = {}
    
    loaded_all = True
    for item in result:
        if item[1] not in data_dict:
            print(f"Form item {item[1]} not found. Data not uploaded.")
            loaded_all = False
            return False
        form_dict[f'entry.{item[4][0][0]}'] = data_dict[item[1]]
    
    post_result = requests.post(post_form_url, data=form_dict)
    return post_result.ok

# %%
from IPython.display import display, Image, HTML, clear_output
import time
import pandas as pd 
import matplotlib.pyplot as plt
#this is the function that checks if the inputed answer is correct
def check_answer(userRes,penalty_time):
    correct_answer = False
    while not correct_answer:
        res_of_user = input("Please put your answer (a-d) here: ").strip().lower()
        if res_of_user == userRes:
            print("Correct!")
            correct_answer = True
        else:
            print("Incorrect. Try again.")
            penalty_time += 20 
    return penalty_time 
start_time = time.time()
#the penalty time is used to calculate the correctness as an indicator of how many attemps the user had.
penalty_time = 0 

#Begining of the test
des1 = HTML("<h3>Welcome to the spatial reasoning test</h3>")
display(des1)

id_instructions = """
Enter your anonymised ID
To generate an anonymous 4-letter unique user identifier please enter:
- two letters based on the initials (first and last name) of a childhood friend
- two letters based on the initials (first and last name) of a favourite actor / actress
e.g. if your friend was called Charlie Brown and film star was Tom Cruise
then your unique identifer would be CBTC
"""
print(id_instructions)
Name = input("> ").strip()
print("User entered id:", Name)
print("")
print("please enter you gender here (Male or Female)")
Gender = input("> ").lower().strip()

print()
print(f"Hello {Name}, please complete all the questions, this will take approximately 3 minutes.")
print()
print("Take your time and think carefully for each question.") 
time.sleep(5)

# Question 1 
question1 = Image("question1.png", width=200)
des2 = HTML("<span>Which image cannot be made by rotating the cube arrangement?</span>")

display(question1)
display(des2)

answer_sets1 = """
<div style='width: 100%; display: flex; justify-content: space-around;'>
    <div><img src='Response1.png' style='width: 100px;'/><p>A</p></div>
    <div><img src='Response2.png' style='width: 100px;'/><p>B</p></div>
    <div><img src='Response3.png' style='width: 100px;'/><p>C</p></div>
    <div><img src='Response4.png' style='width: 100px;'/><p>D</p></div>
</div>
"""

display(HTML(answer_sets1))
#the check_answer function will return the penalty_time in this question, which is added to the total penalty time.
penalty_time = check_answer("d",penalty_time)
time.sleep(1)
clear_output()

#Question 2
question2 = Image("question2.png", width=300)

display(question2)
display(des2)

print("The 2 green blcoks are hanging at the top of the empty corner(3, 0, 2:4)")
answer_sets2 = """
<div style = 'width : 100%; display : flex; justify-content: space-around;'>
    <div><img src = 'Answer2-1.png' style = 'width:100px;'/><p>'A'</p></div>
    <div><img src = 'Answer2-2.png' style = 'width:100px;'/><p>'B'</p></div>
    <div><img src = 'Answer2-3.png' style = 'width:100px;'/><p>'C'</p></div>
    <div><img src = 'Answer2-4.png' style = 'width:100px;'/><p>'D'</p></div>
</div>
"""
display(HTML(answer_sets2))
penalty_time = check_answer("a",penalty_time)
time.sleep(1)
clear_output()

#Question 3 
question3 = """
<div style ='width : 100%; display: flex; justify-content: space-around;'>
    <div><img src = 'question3-p1.png' style = 'width:200px;'/></div>
    <div><img src = 'question3-p2.png' style = 'width:200px;'/></div>
</div>
"""
display(HTML(question3))
display(des2)

answer_sets3 = """
<div style ='width: 100%; display: flex; justify-content:space-around;'>
    <div><img src ='answer3-1.png' style = 'width:100px;'/><p>'A'</p></div>
    <div><img src ='answer3-2.png' style = 'width:100px;'/><p>'B'</p></div>
    <div><img src ='answer3-3.png' style = 'width:100px;'/><p>'C'</p></div>
    <div><img src ='answer3-4.png' style = 'width:100px;'/><p>'D'</p></div>
"""
display(HTML(answer_sets3))

penalty_time = check_answer("d",penalty_time)
time.sleep(1)
clear_output()

#Question 4 
question4 = """
<div style ='width : 100%; display: flex; justify-content: space-around;'>
    <div><img src = 'Question4-p1.png' style = 'width:200px;'/></div>
    <div><img src = 'Question4-p2.png' style = 'width:200px;'/></div>
</div>
"""
display(HTML(question4))
display(des2)

answer_sets4 = """
<div style ='width: 100%; display: flex; justify-content:space-around;'>
    <div><img src ='Answer4-1.png' style = 'width:100px;'/><p>'A'</p></div>
    <div><img src ='Answer4-2X.png' style = 'width:100px;'/><p>'B'</p></div>
    <div><img src ='Answer4-3.png' style = 'width:100px;'/><p>'C'</p></div>
    <div><img src ='Answer4-4.png' style = 'width:100px;'/><p>'D'</p></div>
"""
display(HTML(answer_sets4))

penalty_time = check_answer("b",penalty_time)
time.sleep(1)
clear_output()

#Question5 
question5 = """
<div style ='width : 100%; display: flex; justify-content: space-around;'>
    <div><img src = 'Question5-p1.png' style = 'width:200px;'/></div>
    <div><img src = 'Question5-p2.png' style = 'width:200px;'/></div>
</div>
"""
display(HTML(question5))
display(des2)

answer_sets5 = """
<div style ='width: 100%; display: flex; justify-content:space-around;'>
    <div><img src ='Answer5-1x.png' style = 'width:100px;'/><p>'A'</p></div>
    <div><img src ='Answer5-2.png' style = 'width:100px;'/><p>'B'</p></div>
    <div><img src ='Answer5-3.png' style = 'width:100px;'/><p>'C'</p></div>
    <div><img src ='Answer5-4.png' style = 'width:100px;'/><p>'D'</p></div>
"""
display(HTML(answer_sets5))

penalty_time = check_answer("a",penalty_time)
time.sleep(1)
clear_output()

#time calculations
end_time = time.time()
time_taken = end_time - start_time
time_taken = round(time_taken, 2)
print(f"You have used {time_taken} seconds")
print("The average time taken is 162.29 seconds")

#Correctness calculation:
total_attempts = 5 + (penalty_time / 20)
correctness = (5 / total_attempts) * 100
correctness = round(correctness, 2)
print(f"your correctness is {correctness}%.")
print("The average correctness is 50.23% ")

#calculating the user ranking based on the pool of response:
user_correctness = correctness
df = pd.read_excel("BIOS0030_Results.xlsx")
data = list(df["Correctness(%)"])
data.append(user_correctness)
sorted_data = sorted(data, reverse = True)
ranking = sorted_data.index(user_correctness) + 1 
print(f"You ranking is {ranking} among all the test takers")

# Plotting the results:
plt.figure(figsize=(10,6))
plt.hist(data, bins=10, alpha=0.7, label="Baseline Correctness")
plt.axvline(user_correctness, color="r", linestyle="dashed", linewidth=2, label="Your Correctness")
plt.title("Distribution of Correctness and Your Correctness")
plt.xlabel("Correctness")
plt.ylabel("Frequency")
plt.legend()
plt.show()

#Stroring results into Google Form 
results = {
    "Name": [Name],
    "Time-Taken": [time_taken],
    "Correctness(%)":[correctness],
    "Gender":[Gender],
}

form_url = "https://docs.google.com/forms/d/e/1FAIpQLSf2hZ_UW8WvNb0JReFzNRGzHv0JlrR_Mx9jyhU1g52j7oqE0w/viewform?usp=sf_link"
print("")
print("Please read:")
print("")
print("we wish to record your response data")
print("to an anonymised public data repository. ")
print("Your data will be used for educational teaching purposes")
print("practising data analysis and visualisation.")
print("")
print("Please type yes in the box below if you consent to the upload.")
result2 = input("> ").lower().strip()
if result2 == "yes":
    print("Thanks - your data will be uploaded.") 
    print("Please contact philip.lewis@ucl.ac.uk")
    print("If you have any questions or concerns")
    print("regarding the stored results.")
    send_to_google_form(results, form_url)
else:
    print("No problem we hope you enjoyed the test.")
